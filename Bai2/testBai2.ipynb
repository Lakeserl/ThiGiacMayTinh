# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = Image.open("C:\\Users\\dinhl\\Documents\\GitHub\\ThiGiacMayTinh\\img\\cat_01.jpg")

# %%
# Thay đổi kích thước hình ảnh
new_size = (700, 500) # Kích thước mới của ảnh
resized_image = image.resize(new_size)
# Định nghĩa khu vực cần cắt
# crop_area = (50, 50, 200, 200)  # (trái, trên, phải, dưới)
# cropped_image = image.crop(crop_area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Thay đổi kích thước hình ảnh
#       2 new_size = (700, 500) # Kích thước mới của ảnh
# ----> 3 resized_image = image.resize(new_size)
#       4 # Định nghĩa khu vực cần cắt
#       5 # crop_area = (50, 50, 200, 200)  # (trái, trên, phải, dưới)
#       6 # cropped_image = image.crop(crop_area)
#
# NameError: name 'image' is not defined
